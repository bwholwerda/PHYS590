# %% [markdown]
# # Structure of the Virgo Cluster of Galaxies
#
# ## Authors
# B.W. Holwerda
#
# ## Learning Goals
# * Kinematic estimates of Dark matter in spheroids
# * Kinematic
#
# ## Keywords
# Example, example, example
#
# ## Companion Content
# Ryden & Peterson's "Foundations in Astrophysics"
#
# ## Summary
# Evidence of dark matter in galaxies is predominantly from their kinematics.
#
# rotation curve and T-F data from: http://astroweb.case.edu/ssm/data/
#
# 1.
#
# <hr>

# %% [markdown]
# ## Student Name and ID:
#
#
#
# ## Date:
#
# <hr>

# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from astropy.io import ascii
from astropy.io import fits
from astropy.io import ascii

data = ascii.read("virgo_cluster.txt")  
print(data)
# data from http://iopscience.iop.org/article/10.1088/0067-0049/215/2/22/meta#apjs502304t2
# Out:
# EVCC VCC NGC   RAdeg    DEdeg   FRAdeg  ... e_imag  zmag e_zmag  Rad    R50
#                 deg      deg     deg    ...  mag    mag   mag   arcsec arcsec
# ---- --- ---- -------- ------- -------- ... ------ ----- ------ ------ ------
#    1  --   -- 175.0771    9.01 175.0771 ...   0.02 12.01  0.031  50.02   8.89
#    2  --   -- 175.2362 14.0745 175.2364 ...  0.021 15.13  0.033   36.2   7.59
#    3  -- 3810 175.2449 11.4711 175.2448 ...   0.02 10.01  0.031 137.27  34.31
#    4  --   -- 175.4609 15.9737  175.461 ...   0.02 13.77  0.031  26.02   5.93
#    5  --   -- 175.5747 14.9949 175.5793 ...  0.021 15.52  0.037 106.17  22.43
#    6  --   -- 175.6224 18.3327 175.6228 ...   0.02 12.95  0.031 101.42  21.45
#    7  --   -- 175.8163 -1.3951 175.8172 ...  0.021 16.26  0.036  21.05    5.2
#    8  --   -- 175.8624 11.3985 175.8624 ...  0.021 15.79  0.033  17.41   4.82
#    9  --   -- 175.9422 13.7076 175.9422 ...  0.021 15.23  0.032  13.93   2.83
# ...

# %% [markdown]
# ## Exercise 1 Plot RA & DEC

# %%
# student work

ax = plt.subplot(111)
ax.plot(data['RAdeg'], data['DEdeg'], 'k.')
xlabel('RA (deg)')
ylabel('DEC (deg)')
#ax.set_ylim([0.0, 10000.0])
ax.grid(True)

plt.show()

print(data['PMorph'])
# Out:
#  PMorph
# --------
#       Sa
#        S
#       Sc
# Irr(HSB)
# Irr(LSB)
#       Sc
# Irr(LSB)
# Irr(HSB)
#       S0
# Irr(LSB)
#      ...
#       Sa
# Irr(HSB)
#       Sm
#        S
#       Sb
#        S
#  edge-on
#       Sm
#       Sm
# Irr(HSB)
#       Sm
# Length = 1589 rows

# %%
Sb = np.where(data['PMorph']=='Sb')
Sa = np.where(data['PMorph']=='Sa')
S0 = np.where(data['PMorph']=='S0')
lsb = np.where(data['PMorph']=='Irr(LSB)')
hsb = np.where(data['PMorph']=='Irr(HSB)')
dE = np.where(data['PMorph']=='dE')
E = np.where(data['PMorph']=='E')

# plot different morphjologies with different colors

# %% [markdown]
# ## Plot where Sb and Elliptical galaxies are

# %%
# where are the Sb and E type galaixes? Discuss

# %% [markdown]
# ## Plot IRR LSB and IRR HSB

# %%
# Irr/LCb and Irr?HSB

# %%
# Make plot with vertical (default) colorbar
import matplotlib.pyplot as plt

scatter(data['RAdeg'], data['DEdeg'], lw=0.1,
            c=(data['gmag']-data['imag']), cmap=plt.cm.get_cmap('cubehelix', 6))
colorbar(ticks=range(6), label='g-i')
# plt.clim(-0.5, 5.5)

# discuss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-26cf89a8486c> in <module>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 scatter(data['RAdeg'], data['DEdeg'], lw=0.1,
#       5             c=(data['gmag']-data['imag']), cmap=plt.cm.get_cmap('cubehelix', 6))
#       6 colorbar(ticks=range(6), label='g-i')
#
# NameError: name 'scatter' is not defined

# %% [markdown]
# ## Discuss these colors what do you notice

# %% [markdown]
# * yiour answer here*
